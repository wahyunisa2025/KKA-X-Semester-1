# %% [markdown]
# <a href="https://colab.research.google.com/github/wahyunisa2025/KKA-X-Semester-1/blob/main/2_Tipe_variabel_Berliyana_wn_X_8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Nama      : Berliyana wahyu nissa
#
# Kelas     : X.8
#
# No. absen : 08

# %% [markdown]
# #Konsep Dasar Variabel

# %%
print("berliyanawahyunissa.2025@gmail.com")
print("berliyanawahyunissa.2025@gmail.com")
print("berliyanawahyunissa.2025@gmail.com")
# Out:
# berliyanawahyunissa.2025@gmail.com
# berliyanawahyunissa.2025@gmail.com
# berliyanawahyunissa.2025@gmail.com

# %%
email_user_1 ="berliyanawahyunissa.2025@gmail.com"

print(email_user_1)
print(email_user_1)
print(email_user_1)
# Out:
# berliyanawahyunissa.2025@gmail.com
# berliyanawahyunissa.2025@gmail.com
# berliyanawahyunissa.2025@gmail.com

# %% [markdown]
# #Peraturan Penulisan Variabel

# %%
# Hanya boleh huruf, angka, under score
nama siswa 1 = "Azkaal Tifani"
# Out:
#   File "/tmp/ipython-input-3442662055.py", line 2
#     nama siswa 1 = "Azkaal Tifani"
#          ^
# SyntaxError: invalid syntax

# %%
namasiswa1 = "Azkaal Tifani"
nama_mahasiswa_1 ="Yoga Afganistan"

print(namasiswa1)
print(nama_mahasiswa_1)
# Out:
# Azkaal Tifani
# Yoga Afganistan

# %%
# Tidak boleh didahului oleh angka
1_nama_guru = "Shinta Hanafia"

print(1_nama_guru)
# Out:
#   File "/tmp/ipython-input-3176402443.py", line 2
#     1_nama_guru = "Shinta Hanafia"
#      ^
# SyntaxError: invalid decimal literal

# %%
#Sensitif terhadap kapital
tinggi_badan_1 = 150

print(Tingi_badan_1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-833623930.py in <cell line: 0>()
#       2 tinggi_badan_1 = 150
#       3
# ----> 4 print(Tingi_badan_1)
#
# NameError: name 'Tingi_badan_1' is not defined

# %%
# Tidak boleh dengan kata kunci phyton
class = "X.8"

print(class)
# Out:
#   File "/tmp/ipython-input-355726921.py", line 2
#     class = "X.8"
#           ^
# SyntaxError: invalid syntax

# %%
#Tidak error tapi tidak deskriptif
_ = "Farros Aleaa"

print(_)

nama_mahasiswa_itb = "Farros Taulany"
print(nama_mahasiswa_itb)
# Out:
# Farros Aleaa
# Farros Taulany

# %%
nama_buah = "apel"

print(nama_buah)
# Out:
# apel

# %%
oharga_buah = 15000

print(harga_buah)
# Out:
# 15000

# %%
kasir_1 = "Kareena"

print(kasir_1)
# Out:
# Kareena

# %% [markdown]
# #Assigment

# %%
#single Assigment

harga_rinso = 10000

print(harga_rinso)
# Out:
# 10000

# %%
harga_molto = 30000
harga_pepsodent = 15000
harga_pocari = 10000

print (harga_molto)
print (harga_pepsodent)
print (harga_pocari)
# Out:
# 30000
# 15000
# 10000

# %%
#Multiple assigment

harga_telur, harga_royco, harga_walls = 26000,5000,10000

print(harga_telur)
print(harga_royco)
print(harga_walls)
# Out:
# 26000
# 5000
# 10000

# %%
nama_siswa_1, nilai_uh_kka_1 = "Shinta Hanafia", 90

print(nama_siswa_1)
print(nilai_uh_kka_1)
# Out:
# Shinta Hanafia
# 90

# %%
nama_siswa_1, nilai_uh_kka_1 = "Shinta Hanafia", 90,"Muhammad Abdullah"

print(nama_siswa_1)
print(nilai_uh_kka_1)
print(nama_ortu_1
# Out:
#   File "/tmp/ipython-input-2128911316.py", line 5
#     print(nama_ortu_1
#                      ^
# SyntaxError: incomplete input

# %%
nilai_yoga = 100
nilai_farros = 100
nilai_lisaan = 100

# %%
nilai_yoga, nilai_farros, nilai_lisaan = 100,100,100

# %%
# Chain Assigment
nilai_yoga = nilai_farros = nilai_lisaan = 100

# %%
print(nilai_yoga, nilai_farros, nilai_lisaan)
# Out:
# 100 100 100

# %% [markdown]
# #Cara penggunaan operator di phyton

# %%
#Tanpa variabel
print(9+3)
# Out:
# 12

# %%
print("9+3")
# Out:
# 9+3

# %%
print(sembilan plus tiga)
# Out:
#   File "/tmp/ipython-input-3845315770.py", line 1
#     print(sembilan plus tiga)
#           ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
#operand disimpan ke variabel
buku_tulis_yoga = 9
buku_tulis_yogi = 3

print(buku_tulis_yoga + buku_tulis_yogi)
# Out:
# 12

# %%
#hasil operasi disimpan ke variabel
total_buku_tulis =9+3

print(total_buku_tulis)
# Out:
# 12

# %%
#Operand dan hasil operasi disimpan ke variabel

buku_tulis_yoga =9
buku_tulis_yogi =3
total_buku_tulis = buku_tulis_yoga + buku_tulis_yogi

print(total_buku_tulis)
# Out:
# 12

# %%
#penjumlahan

apel_shinta = 5
apel_aurin = 2

total_apel = apel_shinta + apel_aurin

print(total_apel)
# Out:
# 7

# %%
#pengurangan

apel_shinta = 5
apel_aurin = 2

selisih_apel = apel_shinta - apel_aurin

print(selisih_apel)
# Out:
# 3

# %%
#perkalian

jumlah_kardus_air_minum = 3
jumlah_botol_perkardus = 10

total_botol_air_minum = jumlah_kardus_air_minum * jumlah_botol_perkardus

print(total_botol_air_minum)
# Out:
# 30

# %%
#pembagian
total_botol_air_minum = 30
jumlah_anak_yatim =7

jumlah_botol_tiap_anak_yatim = total_botol_air_minum / jumlah_anak_yatim

print(jumlah_botol_tiap_anak_yatim)
# Out:
# 4.285714285714286

# %%
#Pembagian bulat
total_botol_air_minum = 30
jumlah_anak_yatim = 7

jumlah_botol_tiap_anak_yatim = total_botol_air_minum // jumlah_anak_yatim

print(jumlah_botol_tiap_anak_yatim)
# Out:
# 4

# %%
#Sisa bagi
total_botol_air_minum = 30
jumlah_anak_yatim = 7

sisa_bagi_botol = total_botol_air_minum % jumlah_anak_yatim

print(sisa_bagi_botol)
# Out:
# 2

# %%
#perpangkatan

 sisi = 6
 luas_persegi = sisi ** 2

 print(luas_persegi)
# Out:
#   File "/tmp/ipython-input-3073056509.py", line 3
#     sisi = 6
#     ^
# IndentationError: unexpected indent

# %%
sisi = 3
volume_kubus = sisi ** 3

print(volume_kubus)
# Out:
# 27

# %%
luas_persegi = 25
sisi = luas_persegi ** (1/2)
print(sisi)
# Out:
# 5.0

# %%
#Cara 1. Hitung langsung di print

print (24*3)
# Out:
# 72

# %%
#Cara 2: Simpan angka ke variabel, lalu di tampilkan

total_jumlah_botol = 24 * 3

print(total_jumlah_botol)
# Out:
# 72

# %%
# Cara 3: Simpan angka ke variabel, lalu kalikan langsung di print

banyak_botol_per_kardus = 24
jumlah_kardus = 3

print(banyak_botol_per_kardus * jumlah_kardus)
# Out:
# 72

# %%
#Cara 4: Simpan angka ke variabel, hasilnya juga disimpan ke variabel baru, lalu tampilkan

banyak_botol_per_kardus = 24
jumlah_kardus = 3
total_jumlah_botol = banyak_botol_per_kardus * jumlah_kardus

print(total_jumlah_botol)
# Out:
# 72

# %%
#1 Penjumlahan

apel_dina = 8
apel_diberi = 5
total_apel = apel_dina + apel_diberi

print("Jumlah apel Dina sekarang =", total_apel)
# Out:
# Jumlah apel Dina sekarang = 13

# %%
#2 Pengurangan

mangga_dipetik = 30
mangga_dijual = 12
sisa_mangga = mangga_dipetik - mangga_dijual

print(" Sisa mangga =", sisa_mangga)
# Out:
#  Sisa mangga = 18

# %%
#3 Perkalian

jumlah_meja = 6
siswa_per_meja = 4
total_siswa = jumlah_meja * siswa_per_meja

print("Jumlah siswa seluruhnya =", total_siswa)
# Out:
# Jumlah siswa seluruhnya = 24

# %%
#4 Pembagian

roti = 30
orang = 4
roti_per_orang = roti / orang

print("Roti yang diterima setiap orang =", roti_per_orang)
# Out:
# Roti yang diterima setiap orang = 7.5

# %%
#5 Pembagian Bulat & Sisa Bagi

roti = 30
orang = 4
roti_utuh_per_orang = roti // orang
sisa_roti = roti % orang
print(" Roti utuh per orang =", roti_utuh_per_orang)
print(" Sisa roti =" , sisa_roti)
# Out:
#  Roti utuh per orang = 7
#  Sisa roti = 2

# %%
#6 Sisa bagii

jumlah_donat = 25
jumlah_anak = 6

total_sisa_bagi = jumlah_donat & jumlah_anak

print(total_sisa_bagi)
# Out:
# 0

# %%
#7 Perpangkatan (Luas Persegi)

sisi_persegi = 7
luas_taman = sisi_persegi ** 2
print("Luas taman persegi =", luas_taman, "m²")
# Out:
# Luas taman persegi = 49 m²

# %%
#8 Akar Kuadrat (Persegi)

luas_persegi = 81
sisi_persegi = luas_persegi ** 0.5

print("Panjang sisi persegi =", sisi_persegi, "meter")
# Out:
# Panjang sisi persegi = 9.0 meter

# %%
#9 Akar Pangkat Tiga (Kubus)

volume_kubus = 64
sisi_kubus = volume_kubus ** (1/3)

print("Panjang sisi kubus =", round(sisi_kubus), "meter")
# Out:
# Panjang sisi kubus = 4 meter

# %% [markdown]
# #Jenis-jenis Tipe Variabel

# %%
a = 0
print(a)
type(a)
# Out:
# 0
# int

# %%
b = 0.0
print(b)
type(b)
# Out:
# 0.0
# float

# %%
c = "Hasyim"
print(c)
type(c)
# Out:
# Hasyim
# str

# %%
d = true
print(d)
type(d)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3721722550.py in <cell line: 0>()
# ----> 1 d = true
#       2 print(d)
#       3 type(d)
#
# NameError: name 'true' is not defined

# %%
d = True
print(d)
type(d)
# Out:
# True
# bool

# %%
e = "False"
print(e)
type(e)
# Out:
# False
# str

# %%
f = 9,9
print(f)
type(f)
# Out:
# (9, 9)
# tuple

# %%
type (8.1)
# Out:
# float

# %% [markdown]
# #Mengubah Tipe Variabel

# %%
x = 8
print(x)
type(x)
# Out:
# 8
# int

# %%
x = float (x)
print(x)
type(x)
# Out:
# 8.0
# float

# %%
z = 10
print(z)
type(z)
# Out:
# 10
# int

# %%
z = float (z)
print(z)
type (z)
# Out:
# 10.0
# float

# %%
k = True
print(k)
type(k)
# Out:
# True
# bool

# %%
k = int(k)
print(k)
type(k)
# Out:
# 1
# int

# %%
m = 2
print(m)
type(m)
# Out:
# 2
# int

# %%
m = bool(m)
print(m)
type(m)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3817402374.py in <cell line: 0>()
# ----> 1 m = bool(m)
#       2 print(m)
#       3 type(m)
#
# NameError: name 'm' is not defined

# %%
n = 0.0
print(n)
type(n)
# Out:
# 0.0
# float

# %%
n = bool(n)
print(n)
type(n)
# Out:
# False
# bool

# %%
h = float(5)
print(h)
type(h)
# Out:
# 5.0
# float

# %% [markdown]
# #Operator Perbandingan

# %%
print(5 > 3)
# Out:
# True

# %%
print(5 < 3)
# Out:
# False

# %%
print(6 >= 5)
# Out:
# True

# %%
print(6 <= 6)
# Out:
# True

# %%
print( 6 != 6 )
# Out:
# False

# %%
print ( 7 == 8)
# Out:
# False

# %% [markdown]
# #Operator Logika

# %%
print( 8 > 7 and 6 == 6 )
# Out:
# True

# %%
print( 5 > 2 or 4 <= 4)
# Out:
# True

# %%
print (not( 5 < 2 or 4 >= 4 ))
# Out:
# False

# %%
a = 10
b = 20
c = 30

print(not(a > b and a != c))
# Out:
# True

# %%
nilai_kka = 76
kkm_kka = 75

print(nilai_kka >= kkm_kka)
# Out:
# True

# %%
print( not( 10 == a or c <= 31))
# Out:
# False
